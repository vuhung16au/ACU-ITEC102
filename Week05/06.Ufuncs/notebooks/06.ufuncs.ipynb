# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vuhung16au/ACU-ITEC102/blob/main/Week05/06.Ufuncs/notebooks/06.ufuncs.ipynb)
# [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/vuhung16au/ACU-ITEC102/blob/main/Week05/06.Ufuncs/notebooks/06.ufuncs.ipynb)
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/vuhung16au/ACU-ITEC102/blob/main/Week05/06.Ufuncs/notebooks/06.ufuncs.ipynb)

# %% [markdown]
# [Open this notebook in Google Colab](https://colab.research.google.com/)
#
# # NumPy Built-in Functions (ufuncs)
#
# **Overview:** This notebook covers NumPy built-in functions like mean, sum, and where.

# %% [markdown]
# ## Code Snippets
# The following example demonstrates the core concept of this topic:

# %%
import numpy as np

scores = np.array([45, 92, 55, 30, 88])
grades = np.where(scores >= 50, 'Pass', 'Fail')
print(f"Final Results: {grades}")
# Out:
# Final Results: ['Fail' 'Pass' 'Pass' 'Fail' 'Pass']

# %% [markdown]
# ## Enrichment
# **Broadcasting:** NumPy conceptually stretches scalars to match the size of arrays before performing mathematical operations. This occurs in C-code, providing a huge performance boost over standard Python loops.
# **Upcasting:** If you try to place different types (like `int` and `float`) in a single array, NumPy will implicitly convert them to the most complex type to avoid data loss.

# %% [markdown]
# ## Exercises
# Try to modify the example above to test your understanding.

# %%
# Hint: Use np.array() and perform some basic math operations.
# Solution:
# arr = np.array([1, 2, 3])
# print(arr * 10)

# %% [markdown]
# ## Takeaways
# - np.mean(), np.sum(), np.max(), np.min() are fast ufuncs.
# - np.where() is a powerful function used to categorise data based on conditions.
# ## Conclusion
# NumPy is the bedrock of modern Data Science and AI. Mastering these fundamental array operations is your first major step toward becoming a capable data analyst.
