# %% [markdown]
# # Overview
# This notebook covers **Variable Scope**.

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vuhung/ACU-ITEC102/blob/main/Week04/03.Variable_Scope/notebooks/03_scope.ipynb)
#
# *Note: If the GitHub repository is private or not updated yet, you can download this `.ipynb` file and upload it manually at https://colab.research.google.com/*

# %% [markdown]
# ## Code Snippets
# Here are the code examples demonstrating the concepts.

# %%
def update_balance():
    balance = 500
    return balance

my_balance = update_balance()
print(f'My balance is: ${my_balance}')
# Out:
# My balance is: $500

# %% [markdown]
# ## Enrichment
# Advanced topics and additional information.

# %% [markdown]
# ## Takeaways
# Key points covered in this notebook.

# %% [markdown]
# ## Conclusion
# Summary of the content and its relevance.

# %% [markdown]
# ## Exercises
# Interactive exercises for practice.

# %%
# Try it yourself:

# Solution:
# print('Hello World')
