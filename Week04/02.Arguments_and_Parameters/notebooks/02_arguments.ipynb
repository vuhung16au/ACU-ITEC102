# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vuhung16au/ACU-ITEC102/blob/main/Week04/02.Arguments_and_Parameters/notebooks/02_arguments.ipynb)
# [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/vuhung16au/ACU-ITEC102/blob/main/Week04/02.Arguments_and_Parameters/notebooks/02_arguments.ipynb)
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/vuhung16au/ACU-ITEC102/blob/main/Week04/02.Arguments_and_Parameters/notebooks/02_arguments.ipynb)

# %% [markdown]
# # Overview
# This notebook covers **Arguments and Parameters**.

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vuhung/ACU-ITEC102/blob/main/Week04/02.Arguments_and_Parameters/notebooks/02_arguments.ipynb)
#
# *Note: If the GitHub repository is private or not updated yet, you can download this `.ipynb` file and upload it manually at https://colab.research.google.com/*

# %% [markdown]
# ## Code Snippets
# Here are the code examples demonstrating the concepts.

# %%
def order_coffee(type, size='Medium'):
    return f'Brewing a {size} {type}.'

print(order_coffee('Latte'))
print(order_coffee(size='Large', type='Flat White'))
# Out:
# Brewing a Medium Latte.
# Brewing a Large Flat White.

# %% [markdown]
# ## Enrichment
# Advanced topics and additional information.

# %% [markdown]
# ## Takeaways
# Key points covered in this notebook.

# %% [markdown]
# ## Conclusion
# Summary of the content and its relevance.

# %% [markdown]
# ## Exercises
# Interactive exercises for practice.

# %%
# Try it yourself:

# Solution:
# print('Hello World')
